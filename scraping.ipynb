# %%
from imdb import Cinemagoer
 
# Creating an instance of the Cinemagoer class
ia = Cinemagoer()
 
# Getting movie by IMDb ID
movie = ia.get_movie('0468569')
print(movie)
 
# Printing the names of the directors of the movie
print('Directors:')
 
for director in movie['directors']:
    print(director['name'])
 
# printing the genres of the movie
print('Genres:')
 
for genre in movie['genres']:
    print(genre)
# Out:
# The Dark Knight
# Directors:
# Christopher Nolan
# Genres:
# Action
# Crime
# Drama
# Thriller

# %%
from imdb import Cinemagoer
 
# Creating an instance of the Cinemagoer class
ia = Cinemagoer()
 
# Searching movies that have rock in their name
movies = ia.search_movie('rock')
print(movies)
for movie in movies:
    id = movie['movie_id']
    print(id)
# Out:
# [<Movie id:0117500[http] title:_The Rock (1996)_>, <Movie id:0496424[http] title:_"30 Rock" (2013) (2006)_>, <Movie id:11639952[http] title:_"Young Rock" (2021)_>, <Movie id:0332379[http] title:_School of Rock (2003)_>, <Movie id:1336608[http] title:_Rock of Ages (2012)_>, <Movie id:6548228[http] title:_"Castle Rock" (2019) (2018)_>, <Movie id:0202470[http] title:_Rock Star (2001)_>, <Movie id:0115082[http] title:_"3rd Rock from the Sun" (2001) (1996)_>, <Movie id:2822672[http] title:_Rock Dog (2016)_>, <Movie id:0102802[http] title:_Rock-A-Doodle (1991)_>, <Movie id:17158756[http] title:_"Bocchi the Rock!" (2022)_>, <Movie id:0075148[http] title:_Rocky (1976)_>, <Movie id:1055366[http] title:_Camp Rock (2008) (TV)_>, <Movie id:12397680[http] title:_"Fraggle Rock" (2022)_>, <Movie id:4129004[http] title:_"School of Rock" (2018) (2016)_>, <Movie id:0086203[http] title:_Rock & Rule (1983)_>, <Movie id:1930294[http] title:_Black Rock (2012)_>, <Movie id:10875028[http] title:_Rock and Ro
# ...

# %%
 import imdb
   
# creating instance of IMDb
ia = imdb.IMDb()
   
# name 
name = "3 idiots"
   
# searching the name 
search = ia.search_movie(name)
  
  
# loop for printing the name and id
for i in range(len(search)):
      
    # getting the id
    id = search[i].movieID
      
    # printing it
    print(search[i]['title'] + " : " + id )
# Out:
# 3 Idiots : 1187043
# 3 idiotas : 3685624
# 3 Idiots and a Wise Man : 21612358
# 3 Idiots w/GUNS : 0222441
# 3 Idiots on Wheels : 6689378
# Mugguru Monagallu : 15121916
# Kidnap in Rome : 1575673
# 3 Idiots : 12049418
# Three Idiots : 16345748
# The Idiots : 0154421
# 3 Idiots Try Candy! : 8474256
# Idiots Are People Three! : 2179303
# Confessions of Three Idiots : 21124554
# 159: Three Idiots Yammering : 19944098
# God's Favorite Idiot : 13861620
# 3 Idiots; How Cho Copes with Slump : 9419952
# 3 Pocong Idiot : 2187538
# War of Idiots: Age of Innocence #3 : 9302366
# Bollywood movie: 3 idiots thrii iddiytts : 17915000
# 3 Idiots Movie Review (My First Bollywood Film) : 13274436

# %%
# importing the module
import imdb
   
# creating instance of IMDb
ia = imdb.IMDb()
   
# getting the movie with id
search = ia.get_movie("0111161")
  
# getting movie year
year = search['year']
plot_outline = search['kind']

  
# printing movie name and year
print(search['title'] + " : " + str(year))
print(search.keys())
print(plot_outline)
# Out:
# The Shawshank Redemption : 1994
# ...

# %%
plot_outline = search['imdbID']
print(plot_outline)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-e31b5d66ae16> in <module>
# ----> 1 plot_outline = search['imdbID']
#       2 print(plot_outline)
#
# TypeError: list indices must be integers or slices, not str

# %%
import imdb
# creating an instance of the IMDB()
ia = imdb.IMDb()

user_input = input("Serach a movie or tv series: ")

# Using the Search movie method
items = ia.search_movie(user_input)
for i in items:
    print(i, i[])
print(items)
# Out:
# Mirzapur
# Mirzapur
# Mirzapur Headless Murders
# Mirzapur S2 on Netflix???
# King of Mirzapur
# Lions Of Mirzapur
# Baba meets the Mirzapur gang!
# Reinventing Mirazur
# Mirpur City
# Muzaffarabad & Mirpur
# Mirpur Khas City
# Safari Park Mirpur Mathelo
# Lumír za pultem: part 1
# Lumír za pultem: part 2
# Love and Healing After Tragedy (with Robin Mizaur)
# Is the Clothes Worn by Sania Mirza Permitted?
# 639 Hz a- PURE POSITIVE LOVE ENERGY a- Miracle Tone Healing Music - Heart Chakra Solfeggio Frequency
# ...

# %%
id = items[0]['movie_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-3d4a999b51c2> in <module>
# ----> 1 id = items[0]['movie_id']
#
# /opt/anaconda3/lib/python3.8/site-packages/imdb/utils.py in __getitem__(self, key)
#    1501             rawData = self.data[self.keys_alias[key]]
#    1502         else:
# -> 1503             rawData = self.data[key]
#    1504         if key in self.keys_tomodify and \
#    1505                 self.modFunct not in (None, modNull):
#
# KeyError: 'movie_id'

# %%
# importing the module
import imdb
  
# creating instance of IMDb
ia = imdb.IMDb()
  
# getting top 250 movies
search = ia.get_top250_movies()
 
# printing only first 10 movies title
for i in range(249):
    print(search[i]['title'])
    print(search[i]['year'])
    print(search[i]['rating'])
    print(search[i]['kind'])
    print(search[i]['title'])
    # print(search[i]['genre'])

    print(search[i].keys())

# print(search)
# Out:
# The Shawshank Redemption
# 1994
# 9.2
# movie
# The Shawshank Redemption
# ['rating', 'title', 'year', 'votes', 'top 250 rank', 'kind', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title']
# The Godfather
# 1972
# 9.2
# movie
# The Godfather
# ['rating', 'title', 'year', 'votes', 'top 250 rank', 'kind', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title']
# The Dark Knight
# 2008
# 9.0
# movie
# The Dark Knight
# ['rating', 'title', 'year', 'votes', 'top 250 rank', 'kind', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title']
# The Godfather Part II
# 1974
# 9.0
# movie
# The Godfather Part II
# ...

# %%
# Getting movies and imdb

import imdb

moviesDB = imdb.IMDb()
# print(dir(moviesDB))
movies = moviesDB.search_movie('inception')
for movie in movies:
    title = movie['title']
    print(movie.keys())
    try:
        year = movie['year']
    except:
        year = None
    print(title, year)
    # print(movie.keys())
# Out:
# ['title', 'year', 'kind', 'cover url', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title', 'full-size cover url']
# Inception 2010
# ['title', 'year', 'kind', 'cover url', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title', 'full-size cover url']
# Inception: The Cobol Job 2010
# ['title', 'year', 'kind', 'cover url', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title', 'full-size cover url']
# Bikini Inception 2015
# ['title', 'year', 'kind', 'cover url', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title', 'full-size cover url']
# The Crack: Inception 2019
# ...

# %%
print(movies[0].keys())
movies = moviesDB.search_movie('inception')
id = movies[0].getID()
movie = moviesDB.get_movie(id)
title = movie['title']
print(id)
print(title)
print(movies[1])
# Out:
# ['title', 'year', 'kind', 'cover url', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title', 'full-size cover url']
# 1375666
# Inception
# Inception: The Cobol Job

# %%
a = moviesDB.get_top50_movies_by_genres('action')
for i in a:
    print(i['title'])
    print(i['plot'])
    print(i.keys())
# Out:
# Bullet Train
# Five assassins aboard a swiftly-moving bullet train find out that their missions have something in common.
# ['title', 'certificates', 'runtimes', 'genres', 'rating', 'votes', 'plot', 'directors', 'cast', 'cover url', 'year', 'kind', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title', 'full-size cover url']
# Troll
# Deep in the Dovre mountain, something gigantic wakes up after a thousand years in captivity. The creature destroys everything in its path and quickly approaches Oslo.
# ['title', 'certificates', 'runtimes', 'genres', 'rating', 'votes', 'plot', 'directors', 'cast', 'cover url', 'year', 'kind', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title', 'full-size cover url']
# Violent Night
# When a group of mercenaries attack the estate of a wealthy family, Santa Claus must step in to save the day (and Christmas).
# ...

# %%
for i in a:
# Out:
# [<Movie id:12593682[http] title:_Bullet Train (2022)_>,
#  <Movie id:11116912[http] title:_Troll (2022)_>,
#  <Movie id:12003946[http] title:_Violent Night (2022)_>,
#  <Movie id:1630029[http] title:_Avatar: The Way of Water (2022)_>,
#  <Movie id:1462764[http] title:_Indiana Jones and the Dial of Destiny (2023)_>,
#  <Movie id:0096446[http] title:_Willow (1988)_>,
#  <Movie id:9114286[http] title:_Black Panther: Wakanda Forever (2022)_>,
#  <Movie id:12530246[http] title:_Emancipation (2022)_>,
#  <Movie id:6443346[http] title:_Black Adam (2022)_>,
#  <Movie id:0499549[http] title:_Avatar (2009)_>,
#  <Movie id:5090568[http] title:_Transformers: Rise of the Beasts (2023)_>,
#  <Movie id:6791350[http] title:_Guardians of the Galaxy Vol. 3 (2023)_>,
#  <Movie id:1877830[http] title:_The Batman (2022)_>,
#  <Movie id:6710474[http] title:_Everything Everywhere All at Once (2022)_>,
#  <Movie id:1745960[http] title:_Top Gun: Maverick (2022)_>,
# ...

# %%
# Import the necessary modules
from imdb import IMDb

# Create an instance of the IMDb class
ia = IMDb()

# Get the list of top 250 movies
top_250_movies = ia.

# Loop through the list of movies
for movie_id in top_250_movies:
    # Get the movie's details
    movie = ia.get_movie(movie_id)
    
    # Print the movie's title, rating, and genre
    print(f'{movie["title"]}: {movie["rating"]}, {movie["genre"]}')
# Out:
#   File "<ipython-input-95-ed8bce442917>", line 8
#     top_250_movies = ia.
#                         ^
# SyntaxError: invalid syntax

# %%
import requests
import json
url = "http://www.omdbapi.com/?i=tt3896198&apikey=6a4ba2a0"
response = requests.get(url)
response_json=json.loads(response.text)
print(response_json.keys())
# Out:
# dict_keys(['Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards', 'Poster', 'Ratings', 'Metascore', 'imdbRating', 'imdbVotes', 'imdbID', 'Type', 'DVD', 'BoxOffice', 'Production', 'Website', 'Response'])

# %%
print(response_json['Title'])
# Out:
# Guardians of the Galaxy Vol. 2

# %%
import imdb
moviesDB = imdb.IMDb()
top_250_movies = moviesDB.get_top250_movies()

# %%
moviesDB.get_top50_movies_by_genres
moviesDB.get_top50_tv_by_genres
moviesDB.get_movie_recommendations

# %%
movie_rec = moviesDB.get_movie_recommendations("1851177")
print(movie_rec)
# Out:
# 2022-12-15 14:49:30,674 CRITICAL [imdbpy] /opt/anaconda3/lib/python3.8/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt1851177', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 308: 'Permanent Redirect'>},); kwds: {}
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/imdb/parser/http/__init__.py", line 222, in retrieve_unicode
#     response = uopener.open(url)
#   File "/opt/anaconda3/lib/python3.8/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/opt/anaconda3/lib/python3.8/urllib/request.py", line 640, in http_response
#     response = self.parent.error(
#   File "/opt/anaconda3/lib/python3.8/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/opt/anaconda3/lib/python3.8/urllib/request.py", line 502, in _call_chain
# ...

# %%
popular_tv = moviesDB.get_popular100_tv()
print(len(popular_tv))
for i in range(10):
    title = popular_tv[i]['title']
    print(title)
# Out:
# 100
# Wednesday
# The White Lotus
# Willow
# Yellowstone
# 1899
# The Peripheral
# The Last of Us
# Andor
# The Crown
# Tulsa King
